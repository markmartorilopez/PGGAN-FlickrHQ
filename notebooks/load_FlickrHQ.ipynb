# %% [markdown]
# # Progressive Growing GAN - Flickr-FacesHQ

# %% [markdown]
# ## Brief
# #### The summarized description of the project here

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %% [markdown]
# ### Load - Locally

# %%
# Variables
data_folder = "thumbnails128x128"
image_height = 128
image_width = 128
batch_size = 64

# All 70k images used for training.
train_data = tf.keras.preprocessing.image_dataset_from_directory(
  data_folder,
  seed=123,
  image_size=(image_height, image_width),
  batch_size=batch_size)
# Out:
# Found 70000 files belonging to 70 classes.

# %% [markdown]
# ### Load - Url

# %%
import pathlib

dataset_url = "https://drive.google.com/drive/folders/1tg-Ur7d4vk1T8Bn0pPpUSQPxlPGBlGfv?usp=sharing"
data_dir = tf.keras.utils.get_file(origin=dataset_url, 
                                   fname='thumbnails128x128', 
                                   untar=True)
data_dir = pathlib.Path(data_dir)

image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# ...
#  499712/Unknown - 1s 1us/step0

# %% [markdown]
# ### Visualize

# %%
plt.figure(figsize=(10, 10))
for images,labels  in train_data.take(1):
    for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.axis("off")
